# %%
# %reload_ext autoreload

# %%
# %autoreload 2

# %%
model_path=r'models\mf6'
name='transp_wel'
wel_coords=(0, 15, 15)
qwell = 1
cwell = 100.0 
mixelm = -1

# %%
from make_model import make_input
from make_model import run_simulation
from make_model import show_heads
from make_model import show_well_head
from make_model import show_concentration

# %%
make_input(
    qwell=qwell,
    wel_coords=wel_coords,
    cwell=cwell,
    model_path=model_path,
    name=name, 
    mixelm=mixelm)
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing ims package ims_-1...
#   writing ims package ims_0...
#   writing package transp_wel.gwfgwt...
#   writing model gwf_transp_wel...
#     writing model name file...
#     writing package dis...
#     writing package npf...
#     writing package sto...
#     writing package ic...
#     writing package chd-1...
# INFORMATION: maxbound in ('gwf6', 'chd', 'dimensions') changed to 2 based on size of stress_period_data
#     writing package wel-1...
# INFORMATION: maxbound in ('gwf6', 'wel', 'dimensions') changed to 1 based on size of stress_period_data
#     writing package oc...
#   writing model gwt_transp_wel...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package ssm...
#     writing package oc...
#     writing package obs_0...
# sim_name = transp_wel
# sim_path = C:\TUBAF\MODSIMPLE2\pymf6\doc\examples\transpor_well\models\mf6
# exe_name = mf6
#
# ###################
# Package mfsim.nam
# ###################
#
# package_name = mfsim.nam
# filename = mfsim.nam
# package_type = nam
# model_or_simulation_package = simulation
# simulation_name = transp_wel
#
#
# ###################
# Package transp_wel.tdis
# ###################
#
# package_name = transp_wel.tdis
# filename = transp_wel.tdis
# package_type = tdis
# model_or_simulation_package = simulation
# simulation_name = transp_wel
#
#
# ###################
# Package ims_-1
# ###################
#
# package_name = ims_-1
# filename = gwf_transp_wel.ims
# package_type = ims
# model_or_simulation_package = simulation
# simulation_name = transp_wel
#
#
# ###################
# Package ims_0
# ###################
#
# package_name = ims_0
# filename = gwt_transp_wel.ims
# package_type = ims
# model_or_simulation_package = simulation
# simulation_name = transp_wel
#
#
# ###################
# Package transp_wel.gwfgwt
# ###################
#
# package_name = transp_wel.gwfgwt
# filename = transp_wel.gwfgwt
# package_type = gwfgwt
# model_or_simulation_package = simulation
# simulation_name = transp_wel
#
#
# @@@@@@@@@@@@@@@@@@@@
# Model gwf_transp_wel
# @@@@@@@@@@@@@@@@@@@@
#
# name = gwf_transp_wel
# model_type = gwf6
# version = mf6
# model_relative_path = .
#
# ###################
# Package dis
# ###################
#
# package_name = dis
# filename = gwf_transp_wel.dis
# package_type = dis
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package npf
# ###################
#
# package_name = npf
# filename = gwf_transp_wel.npf
# package_type = npf
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package sto
# ###################
#
# package_name = sto
# filename = gwf_transp_wel.sto
# package_type = sto
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package ic
# ###################
#
# package_name = ic
# filename = gwf_transp_wel.ic
# package_type = ic
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package chd-1
# ###################
#
# package_name = chd-1
# filename = gwf_transp_wel.chd
# package_type = chd
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package wel-1
# ###################
#
# package_name = wel-1
# filename = gwf_transp_wel.wel
# package_type = wel
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
# ###################
# Package oc
# ###################
#
# package_name = oc
# filename = gwf_transp_wel.oc
# package_type = oc
# model_or_simulation_package = model
# model_name = gwf_transp_wel
#
#
#
# @@@@@@@@@@@@@@@@@@@@
# Model gwt_transp_wel
# @@@@@@@@@@@@@@@@@@@@
#
# name = gwt_transp_wel
# model_type = gwt6
# version = mf6
# model_relative_path = .
#
# ###################
# Package dis
# ###################
#
# package_name = dis
# filename = gwt_transp_wel.dis
# package_type = dis
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package ic
# ###################
#
# package_name = ic
# filename = gwt_transp_wel.ic
# package_type = ic
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package adv
# ###################
#
# package_name = adv
# filename = gwt_transp_wel.adv
# package_type = adv
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package dsp
# ###################
#
# package_name = dsp
# filename = gwt_transp_wel.dsp
# package_type = dsp
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package mst
# ###################
#
# package_name = mst
# filename = gwt_transp_wel.mst
# package_type = mst
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package ssm
# ###################
#
# package_name = ssm
# filename = gwt_transp_wel.ssm
# package_type = ssm
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package oc
# ###################
#
# package_name = oc
# filename = gwt_transp_wel.oc
# package_type = oc
# model_or_simulation_package = model
# model_name = gwt_transp_wel
#
#
# ###################
# Package obs_0
# ###################
#
# package_name = obs_0
# filename = gwt_transp_wel.obs
# package_type = obs
# model_or_simulation_package = model
# model_name = gwt_transp_wel

# %%
run_simulation(model_path=model_path)

# %%
show_heads(model_path=model_path, name=name)

# %%
show_well_head(model_path=model_path, name=name, wel_coords=wel_coords)
# Out:
# <Axes: xlabel='Time [d]', ylabel='Water level [m]'>

# %%
show_concentration(model_path=model_path, name=name, wel_coords=wel_coords)
# Out:
# <Axes: xlabel='Time [d]', ylabel='Concentration [mg/l]'>
